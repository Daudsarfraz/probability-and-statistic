# %%
import matplotlib  
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np 

import warnings
warnings.simplefilter("ignore")

# %%
import pandas as pd
data = "nhanes_2015_2016.csv"
df = pd.read_csv(data)

# %% [markdown]
# # Studying Discrete Values

# %%
gender = da['RIAGENDR'] # to calculate the frequency of male and female
gender.value_counts()
# Out:
# 2    2976
# 1    2759
# Name: RIAGENDR, dtype: int64

# %%
gender.value_counts().plot(kind='bar') # visualize the values of Genders
plt.show()

# %%
gender.value_counts().plot(kind='bar')
plt.xticks([0, 1], ['Male', 'Female']) # 0 and 1 mean Inedx Not 2 and 1
plt.xlabel("Gender")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Most Common Value

# %%
sizes = np.array([22, 23, 29, 32, 39, 42, 42, 42, 42, 42, 42, 42, 42, 43, 44, 46, 51, 51, 55, 55, 57, 58, 78, 83, 97, 97]) # lets its data of T-Shirt size

# %%
sizes.mean() # now no will purchase the 49 Size on average calculated
# Out:
# 49.84615384615385

# %%
from collections import Counter 
cnt = Counter()

for size in sizes: 
    cnt[size] += 1 
    
cnt.most_common()         # index 0 is the most common i.e. the mode
# Out:
# [(42, 8),
#  (51, 2),
#  (55, 2),
#  (97, 2),
#  (22, 1),
#  (23, 1),
#  (29, 1),
#  (32, 1),
#  (39, 1),
#  (43, 1),
#  (44, 1),
#  (46, 1),
#  (57, 1),
#  (58, 1),
#  (78, 1),
#  (83, 1)]

# %% [markdown]
# ### Alternative method: use the scipy library

# %%
# !pip install scipy
# Out:
# Requirement already satisfied: scipy in /home/chattha/Documents/Prob-env/lib/python3.10/site-packages (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /home/chattha/Documents/Prob-env/lib/python3.10/site-packages (from scipy) (1.24.2)

# %%
from scipy import stats
stats.mode(sizes)    # index 0 has value, index 1 has count
# Out:
# ModeResult(mode=array([42]), count=array([8]))

# %%
# From Pandas it does not provide frequency
gender.mode()   # not too useful since we could have got that from the bar chart anyway
# Out:
# 0    2
# Name: RIAGENDR, dtype: int64

# %%
stats.mode(gender) # It is from Scipy it provides frequency
# Out:
# ModeResult(mode=array([2]), count=array([2976]))

# %% [markdown]
# ### More than One "Classes "

# %%
da['HIQ210'].unique()
# Out:
# array([ 2., nan,  1.,  9.])

# %%
da['HIQ210'].value_counts().plot(kind='bar')
plt.show()

# %%
da['HIQ210'].value_counts().plot(kind='pie')  # highly NOT recommended! Further see LaTex ticks manual by Pro. Till Tantau
da["HIQ210"].value_counts()
plt.show()

# %% [markdown]
# # Studying Real-Valued Numbers

# %%
wt = da['BMXWT']

# %%
wt.value_counts().plot(kind='bar')    # this does not work at all 
plt.show()

# %%
wt.hist(bins=2)
plt.show()
# here a loose information whether most people lie in 25/50/75/100 etc

# %%
wt.hist(bins=4)
plt.show()
# here a loose information whether most people lie in 25/50/75/100 etc

# %%
wt.hist(bins=10)
plt.show()

# %% [markdown]
# ### Custom Matplotlib Histogram

# %%
plt.hist(wt, bins=20) 
plt.ylabel('Frequency')
plt.xlabel('Weights');
plt.title("Histogram of Weights in NHANES Dataset")
plt.show()


# bins are suitable at specific range

# %%
plt.hist(wt, bins=200) 
plt.ylabel('Frequency')
plt.xlabel('Weights');
plt.title("Histogram of Weights in NHANES Dataset")
plt.grid()
plt.show()



# bins are suitable at specific range

# %% [markdown]
# ### Prettifying and Styling Matplotlib with Seaborn

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /home/chattha/Documents/Prob-env/lib/python3.10/site-packages (0.12.2)
# Requirement already satisfied: pandas>=0.25 in /home/chattha/Documents/Prob-env/lib/python3.10/site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /home/chattha/Documents/Prob-env/lib/python3.10/site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /home/chattha/Documents/Prob-env/lib/python3.10/site-packages (from seaborn) (1.24.2)
# Requirement already satisfied: packaging>=20.0 in /home/chattha/Documents/Prob-env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/chattha/Documents/Prob-env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/chattha/Documents/Prob-env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/chattha/Documents/Prob-env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/chattha/Documents/Prob-env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/chattha/Documents/Prob-env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/chattha/Documents/Prob-env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/chattha/Documents/Prob-env/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pytz>=2020.1 in /home/chattha/Documents/Prob-env/lib/python3.10/site-packages (from pandas>=0.25->seaborn) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /home/chattha/Documents/Prob-env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)

# %%
import seaborn as sns
sns.set(color_codes=True)
sns.set_style("white")     # See more styling options here: https://seaborn.pydata.org/tutorial/aesthetics.html

# %%
sns.distplot(wt, bins=20, kde=True )   # kde = False       # to get rid of the "trend line"
plt.ylabel('Frequency')
plt.xlabel('Weights');
plt.title("Histogram of Weights in NHANES Dataset")
sns.despine(offset=5, trim=True);  # move axes away 
plt.show()

# %% [markdown]
# See many more options about histograms with seaborn here: https://seaborn.pydata.org/tutorial/distributions.html

# %% [markdown]
# ### Studying Central Tendency

# %%
plt.figure(figsize=(20, 10)) 

x =  range(da['BMXWT'].size)
y =  da['BMXWT']

plt.scatter(x, y, marker='x', s=1)

plt.title("Weights of Individuals")
plt.xlabel("ID of Individual")
plt.ylabel("Weight (kg)")

# plot the estimate line 
p1 = (0, 75)
p2 = (6000, 75)
x_c, y_c = zip(p1, p2)
plt.plot(x_c, y_c, color='red', linewidth=2)
plt.show()

# %%
wt.mean()
# Out:
# 81.34267560889516

# %%
plt.figure(figsize=(20, 5)) 

x =  range(da['BMXWT'].size)
y =  da['BMXWT']

plt.scatter(x, y, marker='x', s=0.5)

plt.title("Weights of Individuals")
plt.xlabel("ID of Individual")
plt.ylabel("Weight (kg)")

# plot the estimate line 
x_c, y_c = ([0, 6000], [75, 75])
plt.plot(x_c, y_c, color='red', linewidth=2)

# plot the estimate line 
x_c, y_c = ([0, 6000], [wt.mean(), wt.mean()])
plt.plot(x_c, y_c, color='green', linewidth=2)

plt.show()

# %% [markdown]
# ## Problem with Arithmetic Mean

# %%
import numpy as np

# %%
num = np.array([3, 4, 9, 17, 18, 20, 22, 23, 29, 32, 39, 42, 42, 42, 51, 197])
# 197 this data point is out-lier bcz it is creating issues for other people

# %%
nums = np.array([3, 4, 9, 17, 18, 20, 22, 23, 29, 32, 39, 42, 42, 42, 51, 97])

# %%
np.mean(nums)
# Out:
# 30.625

# %%
np.mean(num)
# Out:
# 36.875

# %%
# let's try to do a different kind of average: the median! 
np.median(nums)
# Out:
# 26.0

# %% [markdown]
# ## Visualizing Weights Data
# The problem with our weights data is similar.

# %%
wt.max()
# Out:
# 198.9

# %%
wt.min()
# Out:
# 32.4

# %%
wt.median()
# Out:
# 78.2

# %%
plt.figure(figsize=(20, 5)) 

x =  range(da['BMXWT'].size)
y =  da['BMXWT']

plt.scatter(x, y, marker='x', s=0.5)

plt.title("Weights of Individuals")
plt.xlabel("ID of Individual")
plt.ylabel("Weight (kg)")

# plot the estimate line 
x_c, y_c = ([0, 6000], [wt.median(), wt.median()])
plt.plot(x_c, y_c, color='red', linewidth=2)

# plot the estimate line 
x_c, y_c = ([0, 6000], [wt.mean(), wt.mean()])
plt.plot(x_c, y_c, color='green', linewidth=2)

plt.show()

# Median is RED and lies UP to mean
# Mean is GREEN and lies BELOW the Median

# %% [markdown]
# ### Quartiles and Boxplots

# %%
nums = np.array([3, 4, 9, 17, 18, 20, 22, 23, 29, 32, 39, 42, 42, 42, 51, 97])

# %%
np.median(nums)
# Out:
# 26.0

# %%
import statistics

# %%
statistics.quantiles(nums, n=4)
# Out:
# [17.25, 26.0, 42.0]

# %%
statistics.quantiles(wt, n=4)
# Out:
# [43.7, 52.5, 50.1]

# %%
ax = sns.boxplot(x=wt) # Black points are Out-liers

# %%
# like SQL select from table where column name is and condition
#         tabel     ceritera        , column name
male_wt = da.loc[da['RIAGENDR'] == 2, 'BMXWT']  
male_wt
male_wt.mean()             # try .mean()
# Out:
# 76.51676280963693

# %%
female_wt = da.loc[da['RIAGENDR'] == 1, 'BMXWT']
female_wt
female_wt.mean()
# Out:
# 86.57326222876058

# %%
# But there's an easier way 
plt.figure(figsize=(8,8))
sns.set_style("whitegrid") 

ax = sns.boxplot(  x = "RIAGENDR", y = "BMXWT",           data=da               , palette="Set3")

# %%
# But there's an easier way 
plt.figure(figsize=(8,8))
sns.set_style("whitegrid") 

ax = sns.boxplot(  x = "RIAGENDR", y = "BMXWT",           data=da               , palette="Set3")

# %%
# But there's an easier way 
plt.figure(figsize=(10,8))
sns.set_style("whitegrid") 


ax = sns.boxplot(  x = "HIQ210", y = "BMXWT",           data=da               , palette="Set3")

# %%
# Averages are the Measure of Central Tendency
