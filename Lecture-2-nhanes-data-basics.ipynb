# %% [markdown]
# # Getting Started with Data

# %%
import pandas as pd # panda is data management library

# %%
ls # I'm using ubuntu so checking files in current directory
# Out:
#  00-nhanes_data_basics.ipynb  'Discrete Distributions.ipynb'
#  01-data-types.ipynb          'Discrete Distributions - Jupyter Notebook.pdf'
#  02-studying-variables.ipynb   Lecture-2-nhanes-data-basics.ipynb
# 'Data sets'/                   README.md

# %%
file = "Data sets/nhanes_2015_2016.csv" # path of file relative
data = pd.read_csv(file)           # reads data from file

# %%
(data) # printing data (NaN  is Not A Number)
# Out:
#        SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0     83732     1.0     NaN     1.0       1         1        62         3
# 1     83733     1.0     NaN     6.0       1         1        53         3
# 2     83734     1.0     NaN     NaN       1         1        78         3
# 3     83735     2.0     1.0     1.0       2         2        56         3
# 4     83736     2.0     1.0     1.0       2         2        42         4
# ...     ...     ...     ...     ...     ...       ...       ...       ...
# 5730  93695     2.0     2.0     NaN       1         2        76         3
# 5731  93696     2.0     2.0     NaN       2         1        26         3
# 5732  93697     1.0     NaN     1.0       1         2        80         3
# 5733  93700     NaN     NaN     NaN       1         1        35         3
# 5734  93702     1.0     NaN     2.0       2         2        24         3
#
#       DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0          1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# 1          2.0       3.0  ...   140.0    88.0   90.4  171.4    30.8    38.0
# 2          1.0       3.0  ...   132.0    44.0   83.4  170.1    28.8    35.6
# 3          1.0       5.0  ...   134.0    68.0  109.8  160.9    42.4    38.5
# 4          1.0       4.0  ...   114.0    54.0   55.2  164.9    20.3    37.4
# ...        ...       ...  ...     ...     ...    ...    ...     ...     ...
# 5730       1.0       3.0  ...   112.0    46.0   59.1  165.8    21.5    38.2
# 5731       1.0       5.0  ...   116.0    76.0  112.1  182.2    33.8    43.4
# 5732       1.0       4.0  ...   146.0    58.0   71.7  152.2    31.0    31.3
# 5733       2.0       1.0  ...   106.0    66.0   78.2  173.3    26.0    40.3
# 5734       1.0       5.0  ...   114.0    68.0   58.3  165.0    21.4    38.2
#
#       BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0        43.6     35.9     101.1     2.0
# 1        40.0     33.2     107.9     NaN
# 2        37.0     31.0     116.5     2.0
# 3        37.7     38.3     110.1     2.0
# 4        36.0     27.2      80.4     2.0
# ...       ...      ...       ...     ...
# 5730     37.0     29.5      95.0     2.0
# 5731     41.8     42.3     110.2     2.0
# 5732     37.5     28.8       NaN     2.0
# 5733     37.5     30.6      98.9     2.0
# 5734     33.5     26.2      72.5     2.0
#
# [5735 rows x 28 columns]

# %%
data.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0       1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# 1       2.0       3.0  ...   140.0    88.0   90.4  171.4    30.8    38.0
# 2       1.0       3.0  ...   132.0    44.0   83.4  170.1    28.8    35.6
# 3       1.0       5.0  ...   134.0    68.0  109.8  160.9    42.4    38.5
# 4       1.0       4.0  ...   114.0    54.0   55.2  164.9    20.3    37.4
#
#    BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0     43.6     35.9     101.1     2.0
# 1     40.0     33.2     107.9     NaN
# 2     37.0     31.0     116.5     2.0
# 3     37.7     38.3     110.1     2.0
# 4     36.0     27.2      80.4     2.0
#
# [5 rows x 28 columns]

# %%
row, columns = data.shape

# %%
print("Total No of Rows ",row)
# Out:
# Total No of Rows  5735

# %%
print("Total No of Columns ", columns)
# Out:
# Total No of Columns  28

# %% [markdown]
# ### Exploring the contents of a data set
#
# Pandas has a number of basic ways to understand what is in a data set.  For example, above we used the '`shape`' method to determine the numbers of rows and columns in a data set.  The columns in a Pandas data frame have names, to see the names, use the '`columns`' method:

# %%
data.columns     # .size
# Out:
# Index(['SEQN', 'ALQ101', 'ALQ110', 'ALQ130', 'SMQ020', 'RIAGENDR', 'RIDAGEYR',
#        'RIDRETH1', 'DMDCITZN', 'DMDEDUC2', 'DMDMARTL', 'DMDHHSIZ', 'WTINT2YR',
#        'SDMVPSU', 'SDMVSTRA', 'INDFMPIR', 'BPXSY1', 'BPXDI1', 'BPXSY2',
#        'BPXDI2', 'BMXWT', 'BMXHT', 'BMXBMI', 'BMXLEG', 'BMXARML', 'BMXARMC',
#        'BMXWAIST', 'HIQ210'],
#       dtype='object')

# %% [markdown]
# These names correspond to variables in the NHANES study. Details of these are here:
#
# https://wwwn.cdc.gov/nchs/nhanes/continuousnhanes/default.aspx?BeginYear=2015
#
# For convenience, direct links to some of the code books are included below:
#
# * [Demographics code book](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/DEMO_I.htm)
#
# * [Body measures code book](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/BMX_I.htm)
#
# * [Blood pressure code book](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/BPX_I.htm)
#
# * [Alcohol questionaire code book](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/ALQ_I.htm)
#
# * [Smoking questionaire code book](https://wwwn.cdc.gov/Nchs/Nhanes/2015-2016/SMQ_I.htm)

# %%
#  BMXWT is the weight in kg 
# [] brackets is symbol of dictionary in python.Panda called tables as data frames
# frame is dictionary. column name is key and values are value of key.
# the values are list of values of that key.

# %%
data['BMXWT'] #1st way  # also use with .head()
data['BMXWT'].head() # 2nd way to access values
# Out:
# 0     94.8
# 1     90.4
# 2     83.4
# 3    109.8
# 4     55.2
# Name: BMXWT, dtype: float64

# %%
data["BMXWT"]
# Out:
# 0        94.8
# 1        90.4
# 2        83.4
# 3       109.8
# 4        55.2
#         ...
# 5730     59.1
# 5731    112.1
# 5732     71.7
# 5733     78.2
# 5734     58.3
# Name: BMXWT, Length: 5735, dtype: float64

# %% [markdown]
# # Data Visualization

# %%
# prepare some data
y = [6, 12,7, 2, 9,4, 5]

# %%
import matplotlib  # plotting library
import matplotlib.pyplot as plt
#%matplotlib inline

# %%
plt.plot(y, color='green', marker='*', linestyle='dashed',
     linewidth=2, markersize=10)
plt.show()

# %%
# create a figure 
plt.figure(figsize=(10, 5)) # size of the figure

# add a line renderer with legend and line thickness
plt.plot(y,"*")
plt.plot(y)
# also need to make the figure readable -- very important from stats perspective!
plt.title("First Example by Dawood") # title of the graph
plt.xlabel("x values (seconds)") # x-axis lable
plt.ylabel("y values (meters)") # y-axis lable
plt.grid() # show grids which are boxes in backgroung

plt.show()

# %%
data['BMXWT'].size # show values or rows of that column|
# Out:
# 5735

# %%
## Plotting Weights 
# create a figure 
plt.figure(figsize=(30, 15)) 

# add a line renderer with legend and line thickness
x =  range(data['BMXWT'].size)
y =  data['BMXWT']

#plt.scatter(x, y, marker='x', s=5) # x mean small cross already known by 
plt.scatter(x, y, marker = "*", s = 5)
# also need to make the figure readable -- very important from stats perspective!
plt.title("Weights of Individuals")
plt.xlabel("ID of Individual")
plt.ylabel("Weight (kg)")

plt.show()

# %%
sum(y) / len(y) # bcz some values are NaN not a number
# Out:
# nan

# %%
y = y.dropna()    # just remove the values with NaN

# %%
sum(y)
# Out:
# 460887.5999999996

# %%
sum(y) / len(y)
# Out:
# 81.34267560889509

# %%
sum(data["BMXWT"])
# Out:
# nan

# %%
a = data["BMXWT"].dropna()

# %%
sum(a)
# Out:
# 460887.5999999996

# %%
a.size
# Out:
# 5666

# %%
sum(a) / a.size
# Out:
# 81.34267560889509
